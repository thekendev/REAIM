# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings

warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
df = pd.read_csv("/Users/kanayojustice/Documents/Data_scientist_projects/REAIM/research/data/raw_uk_renewable_energy.csv")

# %%
df.head(5)
# Out:
#    Year  Energy from renewable & waste sources  \
# 0  1990                                  1.647
# 1  1991                                  1.634
# 2  1992                                  1.843
# 3  1993                                  1.862
# 4  1994                                  2.528
#
#    Total energy consumption of primary fuels and equivalents  \
# 0                                            225.532
# 1                                            231.288
# 2                                            228.696
# 3                                            231.368
# 4                                            230.739
#
#    Fraction from renewable sources and waste  Hydroelectric power  \
# 0                                      0.007                0.448
# 1                                      0.007                0.398
# 2                                      0.008                0.467
# 3                                      0.008                0.370
# ...

# %%
df.shape
# Out:
# (31, 21)

# %% [markdown]
# # Summary of dataset

# %%
df.describe().T
# Out:
#                                                     count         mean  \
# Year                                                 31.0  2005.000000
# Energy from renewable & waste sources                31.0     7.812000
# Total energy consumption of primary fuels and e...   31.0   226.586161
# Fraction from renewable sources and waste            31.0     0.037516
# Hydroelectric power                                  31.0     0.431323
# Wind, wave, tidal                                    31.0     1.299968
# Solar photovoltaic                                   31.0     0.209581
# Geothermal aquifers                                  31.0     0.001000
# Landfill gas                                         31.0     1.023968
# Sewage gas                                           31.0     0.247387
# Biogas from autogen                                  31.0     0.200161
# Municipal solid waste (MSW)                          31.0     1.118419
# ...

# %% [markdown]
# ## Detailed breakdown of the data columns
# ### 1. Year
#
# **Mean**: 2005
#
# **Range**: 1990 to 2020
#
# **Usage**: This column represents the year of the data entry. It is essential for time-based trend analysis. You can use it to examine changes in renewable energy adoption over time and identify long-term trends or shifts.
#
#
# ###  2. Energy from Renewable & Waste Sources
# **Mean**: 7.81
#
# **Range**: 1.63 to 24.47
#
# **Usage**: This column measures the amount of energy derived from renewable and waste sources in a given year. It is critical for assessing the overall progress in renewable energy adoption and its fluctuations over the years.
#
#
# ###  3. Total Energy Consumption of Primary Fuels and Equivalents
# **Mean**: 226.59
#
# **Range**: 169.44 to 252.81
#
# **Usage**: This represents the total energy consumption across all fuel types. It helps to compare renewable energy consumption against the total energy consumption to understand its share and impact.
#
# ###  4. Fraction from Renewable Sources and Waste
# **Mean**: 0.0375
#
# **Range**: 0.007 to 0.144
#
# **Usage**: This fraction indicates the percentage of energy from renewable sources relative to the total energy consumption. Useful for analyzing the proportion of renewable energy and assessing progress towards renewable energy goals.
# ### 5. Hydroelectric Power
#
# **Mean**: 0.4313
#
# **Range**: 0.278 to 0.580
#
# **Usage**: Measures hydroelectric power contribution. Helps to evaluate the role of hydroelectric energy in the renewable energy mix.
#
# ### 6. Wind, Wave, Tidal
#
# **Mean**: 1.3000
#
# **Range**: 0.001 to 6.481
#
# **Usage**: Indicates the amount of energy from wind, wave, and tidal sources. Useful for assessing the impact and growth of these specific renewable energy sources.
#
# ### 7. Solar Photovoltaic
#
# **Mean**: 0.2096
#
# **Range**: 0.000 to 1.131
#
# **Usage**: Measures the energy from solar photovoltaic sources. Helps analyze trends and growth in solar energy adoption.
#
# ### 8. Geothermal Aquifers
#
# **Mean**: 0.0010
#
# **Range**: 0.001
#
# **Usage**: Represents the contribution of geothermal energy, though minimal. Useful for tracking niche renewable sources.
#
# ### 9. Landfill Gas
#
# **Mean**: 1.0240
#
# **Range**: 0.080 to 1.758
#
# **Usage**: Shows the contribution of landfill gas to renewable energy. Helps in understanding the role of waste-to-energy technologies.
#
# ### 10. Sewage Gas
#
# **Mean**: 0.2474
#
# **Range**: 0.138 to 0.440
#
# **Usage**: Represents sewage gas energy contribution. Useful for analyzing the utilization of sewage-based renewable energy.
#
# ### 11. Biogas from Autogen
#
# **Mean**: 0.2002
#
# **Range**: 0.000 to 1.021
#
# **Usage**: Measures biogas energy from autogenic sources. Important for assessing the role of biogas in renewable energy production.
#
# ### 12. Municipal Solid Waste (MSW)
#
# **Mean**: 1.1184
#
# **Range**: 0.183 to 3.367
#
# **Usage**: Indicates energy derived from municipal solid waste. Useful for evaluating waste-to-energy contributions.
#
# ### 13. Poultry Litter
#
# **Mean**: 0.1536
#
# **Range**: 0.000 to 0.227
#
# **Usage**: Measures energy from poultry litter. Useful for understanding contributions from agricultural waste.
#
# ### 14. Straw
#
# **Mean**: 0.0922
#
# **Range**: 0.007 to 0.338
#
# **Usage**: Represents energy from straw. Important for assessing agricultural biomass contributions.
#
# ### 15. Wood
#
# **Mean**: 1.8441
#
# **Range**: 0.687 to 5.478
#
# **Usage**: Measures energy from wood. Helps analyze the role of wood biomass in renewable energy.
#
# ### 16. Charcoal
#
# **Mean**: 0.0482
#
# **Range**: 0.031 to 0.107
#
# **Usage**: Represents energy from charcoal. Useful for understanding its role in renewable energy.
#
# ### 17. Liquid Bio-fuels
#
# **Mean**: 0.0204
#
# **Range**: 0.000 to 0.202
#
# **Usage**: Measures liquid bio-fuels contribution. Helps evaluate the impact of bio-fuels in renewable energy.
#
# ### 18. Bioethanol
#
# **Mean**: 0.1691
#
# **Range**: 0.000 to 0.492
#
# **Usage**: Indicates energy from bioethanol. Useful for analyzing trends in ethanol-based renewables.
#
# ### 19. Biodiesel
#
# **Mean**: 0.3531
#
# **Range**: 0.000 to 1.335
#
# **Usage**: Represents biodiesel energy contribution. Important for assessing biodiesel's role in renewable energy.
#
# ### 20. Biomass
#
# **Mean**: 0.5941
#
# **Range**: 0.029 to 2.469
#
# **Usage**: Measures energy from biomass. Helps in evaluating the broader biomass energy contributions.
#
# ### 21. Cross-boundary Adjustment
#
# **Mean**: 0.0057
#
# **Range**: 0.000 to 0.018
#
# **Usage**: Represents adjustments for cross-boundary energy trading. Useful for understanding the impact of energy imports/exports on local renewable energy statistics.

# %% [markdown]
# ## General Observations
#
# ### 1. Year
# **Mean**: 2005
#
# **Range**: 1990 to 2020
#
# **Insight**: The dataset spans over 30 years, which allows you to assess long-term trends and shifts in renewable energy adoption. Any significant spikes or drops in specific years could reflect major policy changes or economic events.
#
# ### 2. Renewable Energy Sources
# Energy from Renewable & Waste Sources
#
# **Mean**: 7.81
#
# **Range**: 1.63 to 24.47
#
# **Insight**: This indicates the overall contribution of renewable and waste energy to total energy consumption. A high maximum value compared to the mean suggests that while the average contribution is modest, there are years with significant renewable energy uptake.
#
# ### Fraction from Renewable Sources and Waste
#
# **Mean**: 0.0375 (3.75%)
#
# **Range**: 0.007 to 0.144 (0.7% to 14.4%)
#
# **Insight**: This fraction shows the percentage of energy derived from renewable sources relative to total energy consumption. The low mean and relatively small range indicate that while there are years with significant renewables, overall penetration has been low.
#
# ### 3. Specific Renewable Sources
# **Hydroelectric Power**
#
# **Mean**: 0.4313 (43.13%)
#
# **Range**: 27.8% to 58.0%
#
# **Insight**: Hydroelectric power has been a major contributor to the renewable energy mix. Consistent high values suggest that hydroelectric power is a stable and significant part of the renewable energy landscape.
#
# ### Wind, Wave, Tidal
#
# **Mean**: 1.2999 (129.99%)
#
# **Range**: 0.1% to 648.1%
#
# **Insight**: The range here is broad and indicates that wind, wave, and tidal energy can vary significantly year-to-year. A large maximum value might suggest a year with particularly high wind energy output, possibly due to favorable weather conditions.
#
# ### Solar Photovoltaic
#
# **Mean**: 0.2096 (20.96%)
#
# **Range**: 0.0% to 113.1%
#
# **Insight**: Solar photovoltaic energy has a broad range, indicating growth and variability. The increase in mean value suggests growing adoption and capacity over time.
#
# ### Geothermal Aquifers
#
# **Mean**: 0.0010 (0.10%)
#
# **Range**: 0.1%
#
# **Insight**: The minimal value suggests that geothermal energy has had negligible impact compared to other sources.
#
# ### Landfill Gas
#
# **Mean**: 1.0240 (102.40%)
#
# **Range**: 8.0% to 175.8%
#
# **Insight**: Similar to wind, this high variability suggests that landfill gas contributions can be highly variable, possibly reflecting changes in waste management practices or technologies.
#
# ### Biomass vs. Biodiesel
#
# **Biomass Mean**: 0.5941 (59.41%)
#
# **Biodiesel Mean**: 0.3531 (35.31%)
#
# **Insight**: Biomass contributes more to the renewable energy mix compared to biodiesel. This might indicate a more widespread use of biomass, potentially due to its diverse applications and availability.
#
# ## 4. Outliers and Anomalies
# ### Biomass
#
# **Range**: 2.469 (Maximum) compared to Biodiesel's maximum of 1.335.
#
# **Insight**: If biomass consistently shows higher values than biodiesel, it reflects a higher adoption or efficiency of biomass technologies. Large outliers could indicate specific years with exceptional biomass production or usage.
#
# ### Outliers in General
#
# **Insight**: Large differences between the mean and the maximum values in columns such as Wind, Wave, Tidal, and Biomass might suggest years of extraordinary performance or changes in data reporting.
#
# ## 5. Cross-boundary Adjustment
#
# **Mean**: 0.0057 (0.57%)
#
# **Range**: 0.0% to 1.8%
#
# **Insight**: This small value suggests that cross-boundary energy trading has a minor impact on local renewable energy statistics, but it's still useful for understanding the influence of external factors.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 21 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Year                                                       31 non-null     int64
#  1   Energy from renewable & waste sources                      31 non-null     float64
#  2   Total energy consumption of primary fuels and equivalents  31 non-null     float64
#  3   Fraction from renewable sources and waste                  31 non-null     float64
#  4   Hydroelectric power                                        31 non-null     float64
#  5   Wind, wave, tidal                                          31 non-null     float64
#  6   Solar photovoltaic                                         31 non-null     float64
# ...

# %%
# Defining numerical & categorical features
numerical_features = [feature for feature in df.columns if df[feature].dtype != '0']
categorical_features = [feature for feature in df.columns if df[feature].dtype == '0']


# Print columns
print ('we have {} numerical features: {}'.format(len(numerical_features), numerical_features))
print ('we have {} categorical features: {}'.format(len(categorical_features), categorical_features))
# Out:
# we have 21 numerical features: ['Year', 'Energy from renewable & waste sources', 'Total energy consumption of primary fuels and equivalents', 'Fraction from renewable sources and waste', 'Hydroelectric power', 'Wind, wave, tidal', 'Solar photovoltaic', 'Geothermal aquifers', 'Landfill gas', 'Sewage gas', 'Biogas from autogen', 'Municipal solid waste (MSW)', 'Poultry litter', 'Straw', 'Wood', 'Charcoal', 'Liquid bio-fuels', 'Bioethanol', 'Biodiesel', 'Biomass', 'Cross-boundary Adjustment']
# we have 0 categorical features: []

# %% [markdown]
# # Univariate analysis

# %%
# Adjust figure size to accommodate all subplots
plt.rcParams['figure.figsize'] = (15, 30)
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.02)

# Define the number of rows and columns for the subplots
rows = 7
cols = 3

for i in range(len(numerical_features)):
    ax = plt.subplot(rows, cols, i + 1)
    sns.histplot(x=df[numerical_features[i]], color='blue', ax=ax)
    plt.xlabel(numerical_features[i])
    plt.tight_layout()

# Save plot
plt.savefig('/Users/kanayojustice/Documents/Data_scientist_projects/REAIM/research/visualisations/Univariate_Num.png')
plt.show()

# %%
df[(list(df.columns)[1:])].corr()
# Out:
#                                                     Energy from renewable & waste sources  \
# Energy from renewable & waste sources                                            1.000000
# Total energy consumption of primary fuels and e...                              -0.893684
# Fraction from renewable sources and waste                                        0.995173
# Hydroelectric power                                                              0.633815
# Wind, wave, tidal                                                                0.989714
# Solar photovoltaic                                                               0.947400
# Geothermal aquifers                                                                   NaN
# Landfill gas                                                                     0.567383
# Sewage gas                                                                       0.973005
# ...

# %%
# Adjust figure size to accommodate the heatmap for 21 columns
plt.figure(figsize=(20, 15))

# Create the heatmap with annotations and a coolwarm color map
sns.heatmap(df.corr(numeric_only=True), cmap="coolwarm", annot=True)

# Show the plot
plt.show()

# %%
# Display all columns without truncation
pd.set_option('display.max_columns', None)
df.head(5)
# Out:
#    Year  Energy from renewable & waste sources  \
# 0  1990                                  1.647
# 1  1991                                  1.634
# 2  1992                                  1.843
# 3  1993                                  1.862
# 4  1994                                  2.528
#
#    Total energy consumption of primary fuels and equivalents  \
# 0                                            225.532
# 1                                            231.288
# 2                                            228.696
# 3                                            231.368
# 4                                            230.739
#
#    Fraction from renewable sources and waste  Hydroelectric power  \
# 0                                      0.007                0.448
# 1                                      0.007                0.398
# 2                                      0.008                0.467
# 3                                      0.008                0.370
# ...

# %%
df2 =   continues_features=[feature for feature in numerical_features if len(df[feature].unique())>=20]
print('Continues features :',continues_features, '\n Number of Continues features:', len(continues_features))
# Out:
# Continues features : ['Year', 'Energy from renewable & waste sources', 'Total energy consumption of primary fuels and equivalents', 'Fraction from renewable sources and waste', 'Hydroelectric power', 'Wind, wave, tidal', 'Landfill gas', 'Sewage gas', 'Municipal solid waste (MSW)', 'Poultry litter', 'Wood', 'Charcoal', 'Biodiesel', 'Biomass']
#  Number of Continues features: 14

# %%
for i in numerical_features:
    if i not in continues_features:
        print(i)
# Out:
# Solar photovoltaic
# Geothermal aquifers
# Biogas from autogen
# Straw
# Liquid bio-fuels
# Bioethanol
# Cross-boundary Adjustment

# %% [markdown]
# # Balanced Distribution

# %%
sns.set(style="whitegrid")

# %%
# Plot the histogram with KDE (Kernel Density Estimate)
plt.subplots(figsize=(14, 7))
sns.histplot(df['Energy from renewable & waste sources'], kde=True, color='b', bins=100)

# Set the title and axis labels
plt.title("Distribution of Energy from Renewable & Waste Sources Over Years", weight="bold", fontsize=20, pad=20)
plt.ylabel("Count", weight="bold", fontsize=16)
plt.xlabel("Year", weight="bold", fontsize=16)
# Out:
# Text(0.5, 0, 'Year')

# %%
# Plot the histogram with KDE (Kernel Density Estimate)
plt.subplots(figsize=(14, 7))
sns.histplot(df['Total energy consumption of primary fuels and equivalents'], kde=True, color='b', bins=100)

# Set the title and axis labels
plt.title("Distribution of Total energy consumption of primary fuels and equivalents Over Years", weight="bold", fontsize=20, pad=20)
plt.ylabel("Count", weight="bold", fontsize=16)
plt.xlabel("Year", weight="bold", fontsize=16)
# Out:
# Text(0.5, 0, 'Year')

# %%
# Plot the histogram with KDE (Kernel Density Estimate)
plt.subplots(figsize=(14, 7))
sns.histplot(df['Fraction from renewable sources and waste'], kde=True, color='b', bins=100)

# Set the title and axis labels
plt.title("Distribution of Fraction from renewable sources and waste Over Years", weight="bold", fontsize=20, pad=20)
plt.ylabel("Count", weight="bold", fontsize=16)
plt.xlabel("Year", weight="bold", fontsize=16)
# Out:
# Text(0.5, 0, 'Year')

# %%
plt.subplots(figsize=(14,7))
sns.histplot(df['Hydroelectric power'],bins=20)
plt.title("Hydroelectric power Count", weight="bold",fontsize=20, pad=20)
plt.ylabel("Count", weight="bold", fontsize=12)
plt.xlabel("Year", weight="bold", fontsize=16)

plt.show()

# %%
plt.subplots(figsize=(14,7))
sns.histplot(df['Wind, wave, tidal'],bins=20)
plt.title("Wind, wave, tidal Count", weight="bold",fontsize=20, pad=20)
plt.ylabel("Count", weight="bold", fontsize=12)
plt.xlabel("Year", weight="bold", fontsize=16)

plt.show()

# %%
plt.subplot(1,2,1)
sns.distplot(df['Landfill gas'],color='green')
plt.title('Distribution of Landfill gas', fontsize = 20)
plt.xlabel('Amount')


plt.subplot(1,2,2)
sns.distplot(df['Sewage gas'], color='red')
plt.title('Distribution of Sewage gas', fontsize = 20)
plt.xlabel('Amount')
plt.show()

# %%
plt.subplots(figsize=(12,15))
cols= ['Municipal solid waste (MSW)','Poultry litter','Wood','Charcoal']
for i in range(len(cols)):
    plt.subplot(2,2,i+1)
    sns.scatterplot(x = df[cols[i]],y = df['Municipal solid waste (MSW)'], ec='k', color='c')
    plt.title(f'Municipal solid waste (MSW) And {cols[i]}', fontsize =14)
    plt.xlabel(cols[i])
    plt.ylabel('Municipal solid waste (MSW)')

# %%
cols=['Energy from renewable & waste sources','Total energy consumption of primary fuels and equivalents','Fraction from renewable sources and waste', 'Hydroelectric power','Wind, wave, tidal','Landfill gas']
plt.subplots(figsize=(12,15))
for i in range(len(cols)):
    plt.subplot(3,2,i+1)
    sns.violinplot(df[cols[i]], color='c')
    plt.title(cols[i], fontsize =12)
    plt.xlabel(cols[i])
    plt.tight_layout()

# %%
sns.barplot(y=df['Hydroelectric power'],x=df.Year,palette='bright')
plt.ylabel("Percentage of full Payment done",size=15)
plt.xlabel("Tenure in Months", size=20)
plt.show()

# %%
# Create a DataFrame `df2` containing only the continuous features
df2 = df[continues_features]

# Define the path to save the CSV file
csv_path = '/Users/kanayojustice/Documents/Data_scientist_projects/REAIM/research/data/processed/stage1_preprocessed_data.csv'

# Save `df2` as a CSV file
df2.to_csv(csv_path, index=False)

print(f'DataFrame saved as CSV at: {csv_path}')
# Out:
# DataFrame saved as CSV at: /Users/kanayojustice/Documents/Data_scientist_projects/REAIM/research/data/processed/stage1_preprocessed_data.csv
